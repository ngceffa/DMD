# %%
import dmd_with_power_control_single_task as DMD
import imageio
import numpy as np
import time
from glob import glob
import os
import importlib
importlib.reload(DMD)
import napari as nap

XP_FOLDER = r'D:\Data\OR83b_ppk72__20xpair_trace_subregion_new' # **** D:\Data\G1-2_72F11_ppk\12_mvenus_20240301_172158
TARGET_FOLDER = XP_FOLDER + r'\test' # ***D:\Data\G1D:\Data\G1-2_72F11_ppk\
GENERAL_PARAMETERS = r'C:\\Users\\Light Sheet User\\Desktop\\DMD_parameters.pickled'
mirrors = DMD.dmd(XP_FOLDER, TARGET_FOLDER, GENERAL_PARAMETERS)
# Prints basic information about the DMD.
image = imageio.imread(r'C:\Users\Light Sheet User\Documents\SiMView Configuration\DMD Images\Letter_R.png')
tot = np.ones((image.shape), dtype=np.uint8)
# Out:
# Loading library: C:/Program Files/ALP-4.3/ALP-4.3 API/x64/alp4395.dll
# DMD found, resolution = 1920 x 1200.
# DMD patterns folder already exists.
# c:\Users\Light Sheet User\Documents\GitHub\DMD\dmd_with_power_control_single_task.py:43: ResourceWarning: unclosed file <_io.BufferedReader name='C:\\\\Users\\\\Light Sheet User\\\\Desktop\\\\DMD_parameters.pickled'>
#   self.parameters = pickle.load(open(general_parameters_folder, 'rb'))
# ...
# C:\Users\Light Sheet User\AppData\Local\Temp\ipykernel_5008\2031705555.py:16: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(r'C:\Users\Light Sheet User\Documents\SiMView Configuration\DMD Images\Letter_R.png')

# %% [markdown]
# - draw points to be projected
# - find the projected points in real image
# - run affine

# %%
mirrors.draw_calib_points()

# %%
mirrors.record_theoretical_points()
# Out:
# [ 517.72811645 1263.96985679]
# [709.10916431 823.79344673]
# [722.15787211 804.65534194]
# [736.07649378 781.16766789]

# %%
mirrors.project(mirrors.user_calibration_mask, 2)
# Out:
# DMD ON,  input voltage 2.000000

# %%
mirrors.idle()

# %%
image = imageio.imread(r'C:\Users\Light Sheet User\Documents\GitHub\DMD\user_camera_DMD_calibration.png')
mirrors.select_calibration_points(image)
# Out:
# C:\Users\Light Sheet User\AppData\Local\Temp\ipykernel_5008\2897689892.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(r'C:\Users\Light Sheet User\Documents\GitHub\DMD\user_camera_DMD_calibration.png')

# %%
mirrors.find_calibration_points()

# %%
mirrors.find_affine_from_user_input()
# Out:
# 1209.7001036726062 1249.0849804510542
# 671.2679116622332 918.3965783379565
# [[-0.2675297  -0.96354961]
#  [ 0.96354961 -0.2675297 ]]

# %%
mirrors.idle()

# %%
mirrors.close()
# Out:
# DMD halted.
# DMD closed.
#
# DND laer off.
